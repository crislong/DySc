# %%
import numpy as np
import myfunctions as mf
import class_rotationcurve as rc
import matplotlib.pyplot as plt
plt.rc('xtick', labelsize=16) 
plt.rc('ytick', labelsize=16) 
plt.rcParams.update({'font.size': 15})
fontw = {'family' : 'serif','sans-serif': 'Serif'}
plt.rc('font', **fontw)

# %%
# true values of the data are
# Mstar = 1.12
# Mdisc = 0.19
# Rc = 105
# Hr = 0.095 @ 100au
# q = 0.25 default

# %%
radius = np.loadtxt('Tutorial_data/radius_au.txt')
velocity = np.loadtxt('Tutorial_data/velocity_kms.txt')
error_velocity = np.loadtxt('Tutorial_data/errorvelocity_kms.txt')

hr_100au = 0.095
height = 1/50 * radius

# %% [markdown]
# # Total model fit : Star + Pressure gradient + SG

# %%
rcurve3 = rc.rotationcurve(velocity, error_velocity, radius, 1/50 * radius, hr_100au, 100., model=3)
# for info about input parameters,, run rc.rotationcurve?

# %%
rcurve3.fit(150, 1000,1000)
# Out:
# 100%|██████████| 1000/1000 [00:26<00:00, 37.23it/s]

# %%
rcurve3.plot_model()

# %% [markdown]
# # Without Self gravity

# %%
rcurve2 = rc.rotationcurve(velocity, error_velocity, radius, 1/50 * radius, hr_100au, 100., model=2)

# %%
rcurve2.fit(150, 1000,1000)
# Out:
# 100%|██████████| 1000/1000 [00:13<00:00, 73.12it/s]

# %%
rcurve2.plot_model()
